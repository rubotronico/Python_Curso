# %% [markdown]
# ## Ejemplo de cabecera
# # Titulazo
# Intenta deducir qué hace este programa (no hace falta que le des muchas vueltas).

# %%
n = 0
while n < 10:  # while = mientras
    if (n % 2) == 0: # if = si (de condicion)
        print(n,'es un número par')
    else:  # else = sino (def condicion)
        print(n,'es un número impar')
    n = n + 1
# Out:
# 0 es un número par
# 1 es un número impar
# 2 es un número par
# 3 es un número impar
# 4 es un número par
# 5 es un número impar
# 6 es un número par
# 7 es un número impar
# 8 es un número par
# 9 es un número impar

# %%
n = 0
while n < 1000:  # while = mientras
    if (n % 2) == 0: # if = si (de condicion)
        print(n,'es un número par')
    else:  # else = sino (def condicion)
        print(n,'es un número impar')
    n = n + 1
# Out:
# 0 es un número par
# 1 es un número impar
# 2 es un número par
# 3 es un número impar
# 4 es un número par
# 5 es un número impar
# 6 es un número par
# 7 es un número impar
# 8 es un número par
# 9 es un número impar
# 10 es un número par
# 11 es un número impar
# 12 es un número par
# 13 es un número impar
# 14 es un número par
# 15 es un número impar
# 16 es un número par
# 17 es un número impar
# 18 es un número par
# 19 es un número impar
# 20 es un número par
# 21 es un número impar
# 22 es un número par
# 23 es un número impar
# 24 es un número par
# 25 es un número impar
# 26 es un número par
# 27 es un número impar
# 28 es un número par
# 29 es un número impar
# 30 es un número par
# 31 es un número impar
# 32 es un número par
# 33 es un número impar
# 34 es un número par
# 35 es un número impar
# 36 es un número par
# 37 es un número impar
# 38 es un número par
# 39 es un número impar
# 40 es un número par
# 41 es un número impar
# 42 es un número par
# 43 es un número impar
# 44 es un número par
# 45 es un número impar
# 46 es un número par
# 47 es un número impar
# 48 es un número par
# 49 es un número impar
# 50 es un número par
# 51 es un número impar
# 52 es un número par
# 53 es un número impar
# 54 es un número par
# 55 es un número impar
# 56 es un número par
# 57 es un número impar
# 58 es un número par
# 59 es un número impar
# 60 es un número par
# 61 es un número impar
# 62 es un número par
# 63 es un número impar
# 64 es un número par
# 65 es un número impar
# 66 es un número par
# 67 es un número impar
# 68 es un número par
# 69 es un número impar
# 70 es un número par
# 71 es un número impar
# 72 es un número par
# 73 es un número impar
# 74 es un número par
# 75 es un número impar
# 76 es un número par
# 77 es un número impar
# 78 es un número par
# 79 es un número impar
# 80 es un número par
# 81 es un número impar
# 82 es un número par
# 83 es un número impar
# 84 es un número par
# 85 es un número impar
# 86 es un número par
# 87 es un número impar
# 88 es un número par
# 89 es un número impar
# 90 es un número par
# 91 es un número impar
# 92 es un número par
# 93 es un número impar
# 94 es un número par
# 95 es un número impar
# 96 es un número par
# 97 es un número impar
# 98 es un número par
# 99 es un número impar
# 100 es un número par
# 101 es un número impar
# 102 es un número par
# 103 es un número impar
# 104 es un número par
# 105 es un número impar
# 106 es un número par
# 107 es un número impar
# 108 es un número par
# 109 es un número impar
# 110 es un número par
# 111 es un número impar
# 112 es un número par
# 113 es un número impar
# 114 es un número par
# 115 es un número impar
# 116 es un número par
# 117 es un número impar
# 118 es un número par
# 119 es un número impar
# 120 es un número par
# 121 es un número impar
# 122 es un número par
# 123 es un número impar
# 124 es un número par
# 125 es un número impar
# 126 es un número par
# 127 es un número impar
# 128 es un número par
# 129 es un número impar
# 130 es un número par
# 131 es un número impar
# 132 es un número par
# 133 es un número impar
# 134 es un número par
# 135 es un número impar
# 136 es un número par
# 137 es un número impar
# 138 es un número par
# 139 es un número impar
# 140 es un número par
# 141 es un número impar
# 142 es un número par
# 143 es un número impar
# 144 es un número par
# 145 es un número impar
# 146 es un número par
# 147 es un número impar
# 148 es un número par
# 149 es un número impar
# 150 es un número par
# 151 es un número impar
# 152 es un número par
# 153 es un número impar
# 154 es un número par
# 155 es un número impar
# 156 es un número par
# 157 es un número impar
# 158 es un número par
# 159 es un número impar
# 160 es un número par
# 161 es un número impar
# 162 es un número par
# 163 es un número impar
# 164 es un número par
# 165 es un número impar
# 166 es un número par
# 167 es un número impar
# 168 es un número par
# 169 es un número impar
# 170 es un número par
# 171 es un número impar
# 172 es un número par
# 173 es un número impar
# 174 es un número par
# 175 es un número impar
# 176 es un número par
# 177 es un número impar
# 178 es un número par
# 179 es un número impar
# 180 es un número par
# 181 es un número impar
# 182 es un número par
# 183 es un número impar
# 184 es un número par
# 185 es un número impar
# 186 es un número par
# 187 es un número impar
# 188 es un número par
# 189 es un número impar
# 190 es un número par
# 191 es un número impar
# 192 es un número par
# 193 es un número impar
# 194 es un número par
# 195 es un número impar
# 196 es un número par
# 197 es un número impar
# 198 es un número par
# 199 es un número impar
# 200 es un número par
# 201 es un número impar
# 202 es un número par
# 203 es un número impar
# 204 es un número par
# 205 es un número impar
# 206 es un número par
# 207 es un número impar
# 208 es un número par
# 209 es un número impar
# 210 es un número par
# 211 es un número impar
# 212 es un número par
# 213 es un número impar
# 214 es un número par
# 215 es un número impar
# 216 es un número par
# 217 es un número impar
# 218 es un número par
# 219 es un número impar
# 220 es un número par
# 221 es un número impar
# 222 es un número par
# 223 es un número impar
# 224 es un número par
# 225 es un número impar
# 226 es un número par
# 227 es un número impar
# 228 es un número par
# 229 es un número impar
# 230 es un número par
# 231 es un número impar
# 232 es un número par
# 233 es un número impar
# 234 es un número par
# 235 es un número impar
# 236 es un número par
# 237 es un número impar
# 238 es un número par
# 239 es un número impar
# 240 es un número par
# 241 es un número impar
# 242 es un número par
# 243 es un número impar
# 244 es un número par
# 245 es un número impar
# 246 es un número par
# 247 es un número impar
# 248 es un número par
# 249 es un número impar
# 250 es un número par
# 251 es un número impar
# 252 es un número par
# 253 es un número impar
# 254 es un número par
# 255 es un número impar
# 256 es un número par
# 257 es un número impar
# 258 es un número par
# 259 es un número impar
# 260 es un número par
# 261 es un número impar
# 262 es un número par
# 263 es un número impar
# 264 es un número par
# 265 es un número impar
# 266 es un número par
# 267 es un número impar
# 268 es un número par
# 269 es un número impar
# 270 es un número par
# 271 es un número impar
# 272 es un número par
# 273 es un número impar
# 274 es un número par
# 275 es un número impar
# 276 es un número par
# 277 es un número impar
# 278 es un número par
# 279 es un número impar
# 280 es un número par
# 281 es un número impar
# 282 es un número par
# 283 es un número impar
# 284 es un número par
# 285 es un número impar
# 286 es un número par
# 287 es un número impar
# 288 es un número par
# 289 es un número impar
# 290 es un número par
# 291 es un número impar
# 292 es un número par
# 293 es un número impar
# 294 es un número par
# 295 es un número impar
# 296 es un número par
# 297 es un número impar
# 298 es un número par
# 299 es un número impar
# 300 es un número par
# 301 es un número impar
# 302 es un número par
# 303 es un número impar
# 304 es un número par
# 305 es un número impar
# 306 es un número par
# 307 es un número impar
# 308 es un número par
# 309 es un número impar
# 310 es un número par
# 311 es un número impar
# 312 es un número par
# 313 es un número impar
# 314 es un número par
# 315 es un número impar
# 316 es un número par
# 317 es un número impar
# 318 es un número par
# 319 es un número impar
# 320 es un número par
# 321 es un número impar
# 322 es un número par
# 323 es un número impar
# 324 es un número par
# 325 es un número impar
# 326 es un número par
# 327 es un número impar
# 328 es un número par
# 329 es un número impar
# 330 es un número par
# 331 es un número impar
# 332 es un número par
# 333 es un número impar
# 334 es un número par
# 335 es un número impar
# 336 es un número par
# 337 es un número impar
# 338 es un número par
# 339 es un número impar
# 340 es un número par
# 341 es un número impar
# 342 es un número par
# 343 es un número impar
# 344 es un número par
# 345 es un número impar
# 346 es un número par
# 347 es un número impar
# 348 es un número par
# 349 es un número impar
# 350 es un número par
# 351 es un número impar
# 352 es un número par
# 353 es un número impar
# 354 es un número par
# 355 es un número impar
# 356 es un número par
# 357 es un número impar
# 358 es un número par
# 359 es un número impar
# 360 es un número par
# 361 es un número impar
# 362 es un número par
# 363 es un número impar
# 364 es un número par
# 365 es un número impar
# 366 es un número par
# 367 es un número impar
# 368 es un número par
# 369 es un número impar
# 370 es un número par
# 371 es un número impar
# 372 es un número par
# 373 es un número impar
# 374 es un número par
# 375 es un número impar
# 376 es un número par
# 377 es un número impar
# 378 es un número par
# 379 es un número impar
# 380 es un número par
# 381 es un número impar
# 382 es un número par
# 383 es un número impar
# 384 es un número par
# 385 es un número impar
# 386 es un número par
# 387 es un número impar
# 388 es un número par
# 389 es un número impar
# 390 es un número par
# 391 es un número impar
# 392 es un número par
# 393 es un número impar
# 394 es un número par
# 395 es un número impar
# 396 es un número par
# 397 es un número impar
# 398 es un número par
# 399 es un número impar
# 400 es un número par
# 401 es un número impar
# 402 es un número par
# 403 es un número impar
# 404 es un número par
# 405 es un número impar
# 406 es un número par
# 407 es un número impar
# 408 es un número par
# 409 es un número impar
# 410 es un número par
# 411 es un número impar
# 412 es un número par
# 413 es un número impar
# 414 es un número par
# 415 es un número impar
# 416 es un número par
# 417 es un número impar
# 418 es un número par
# 419 es un número impar
# 420 es un número par
# 421 es un número impar
# 422 es un número par
# 423 es un número impar
# 424 es un número par
# 425 es un número impar
# 426 es un número par
# 427 es un número impar
# 428 es un número par
# 429 es un número impar
# 430 es un número par
# 431 es un número impar
# 432 es un número par
# 433 es un número impar
# 434 es un número par
# 435 es un número impar
# 436 es un número par
# 437 es un número impar
# 438 es un número par
# 439 es un número impar
# 440 es un número par
# 441 es un número impar
# 442 es un número par
# 443 es un número impar
# 444 es un número par
# 445 es un número impar
# 446 es un número par
# 447 es un número impar
# 448 es un número par
# 449 es un número impar
# 450 es un número par
# 451 es un número impar
# 452 es un número par
# 453 es un número impar
# 454 es un número par
# 455 es un número impar
# 456 es un número par
# 457 es un número impar
# 458 es un número par
# 459 es un número impar
# 460 es un número par
# 461 es un número impar
# 462 es un número par
# 463 es un número impar
# 464 es un número par
# 465 es un número impar
# 466 es un número par
# 467 es un número impar
# 468 es un número par
# 469 es un número impar
# 470 es un número par
# 471 es un número impar
# 472 es un número par
# 473 es un número impar
# 474 es un número par
# 475 es un número impar
# 476 es un número par
# 477 es un número impar
# 478 es un número par
# 479 es un número impar
# 480 es un número par
# 481 es un número impar
# 482 es un número par
# 483 es un número impar
# 484 es un número par
# 485 es un número impar
# 486 es un número par
# 487 es un número impar
# 488 es un número par
# 489 es un número impar
# 490 es un número par
# 491 es un número impar
# 492 es un número par
# 493 es un número impar
# 494 es un número par
# 495 es un número impar
# 496 es un número par
# 497 es un número impar
# 498 es un número par
# 499 es un número impar
# 500 es un número par
# 501 es un número impar
# 502 es un número par
# 503 es un número impar
# 504 es un número par
# 505 es un número impar
# 506 es un número par
# 507 es un número impar
# 508 es un número par
# 509 es un número impar
# 510 es un número par
# 511 es un número impar
# 512 es un número par
# 513 es un número impar
# 514 es un número par
# 515 es un número impar
# 516 es un número par
# 517 es un número impar
# 518 es un número par
# 519 es un número impar
# 520 es un número par
# 521 es un número impar
# 522 es un número par
# 523 es un número impar
# 524 es un número par
# 525 es un número impar
# 526 es un número par
# 527 es un número impar
# 528 es un número par
# 529 es un número impar
# 530 es un número par
# 531 es un número impar
# 532 es un número par
# 533 es un número impar
# 534 es un número par
# 535 es un número impar
# 536 es un número par
# 537 es un número impar
# 538 es un número par
# 539 es un número impar
# 540 es un número par
# 541 es un número impar
# 542 es un número par
# 543 es un número impar
# 544 es un número par
# 545 es un número impar
# 546 es un número par
# 547 es un número impar
# 548 es un número par
# 549 es un número impar
# 550 es un número par
# 551 es un número impar
# 552 es un número par
# 553 es un número impar
# 554 es un número par
# 555 es un número impar
# 556 es un número par
# 557 es un número impar
# 558 es un número par
# 559 es un número impar
# 560 es un número par
# 561 es un número impar
# 562 es un número par
# 563 es un número impar
# 564 es un número par
# 565 es un número impar
# 566 es un número par
# 567 es un número impar
# 568 es un número par
# 569 es un número impar
# 570 es un número par
# 571 es un número impar
# 572 es un número par
# 573 es un número impar
# 574 es un número par
# 575 es un número impar
# 576 es un número par
# 577 es un número impar
# 578 es un número par
# 579 es un número impar
# 580 es un número par
# 581 es un número impar
# 582 es un número par
# 583 es un número impar
# 584 es un número par
# 585 es un número impar
# 586 es un número par
# 587 es un número impar
# 588 es un número par
# 589 es un número impar
# 590 es un número par
# 591 es un número impar
# 592 es un número par
# 593 es un número impar
# 594 es un número par
# 595 es un número impar
# 596 es un número par
# 597 es un número impar
# 598 es un número par
# 599 es un número impar
# 600 es un número par
# 601 es un número impar
# 602 es un número par
# 603 es un número impar
# 604 es un número par
# 605 es un número impar
# 606 es un número par
# 607 es un número impar
# 608 es un número par
# 609 es un número impar
# 610 es un número par
# 611 es un número impar
# 612 es un número par
# 613 es un número impar
# 614 es un número par
# 615 es un número impar
# 616 es un número par
# 617 es un número impar
# 618 es un número par
# 619 es un número impar
# 620 es un número par
# 621 es un número impar
# 622 es un número par
# 623 es un número impar
# 624 es un número par
# 625 es un número impar
# 626 es un número par
# 627 es un número impar
# 628 es un número par
# 629 es un número impar
# 630 es un número par
# 631 es un número impar
# 632 es un número par
# 633 es un número impar
# 634 es un número par
# 635 es un número impar
# 636 es un número par
# 637 es un número impar
# 638 es un número par
# 639 es un número impar
# 640 es un número par
# 641 es un número impar
# 642 es un número par
# 643 es un número impar
# 644 es un número par
# 645 es un número impar
# 646 es un número par
# 647 es un número impar
# 648 es un número par
# 649 es un número impar
# 650 es un número par
# 651 es un número impar
# 652 es un número par
# 653 es un número impar
# 654 es un número par
# 655 es un número impar
# 656 es un número par
# 657 es un número impar
# 658 es un número par
# 659 es un número impar
# 660 es un número par
# 661 es un número impar
# 662 es un número par
# 663 es un número impar
# 664 es un número par
# 665 es un número impar
# 666 es un número par
# 667 es un número impar
# 668 es un número par
# 669 es un número impar
# 670 es un número par
# 671 es un número impar
# 672 es un número par
# 673 es un número impar
# 674 es un número par
# 675 es un número impar
# 676 es un número par
# 677 es un número impar
# 678 es un número par
# 679 es un número impar
# 680 es un número par
# 681 es un número impar
# 682 es un número par
# 683 es un número impar
# 684 es un número par
# 685 es un número impar
# 686 es un número par
# 687 es un número impar
# 688 es un número par
# 689 es un número impar
# 690 es un número par
# 691 es un número impar
# 692 es un número par
# 693 es un número impar
# 694 es un número par
# 695 es un número impar
# 696 es un número par
# 697 es un número impar
# 698 es un número par
# 699 es un número impar
# 700 es un número par
# 701 es un número impar
# 702 es un número par
# 703 es un número impar
# 704 es un número par
# 705 es un número impar
# 706 es un número par
# 707 es un número impar
# 708 es un número par
# 709 es un número impar
# 710 es un número par
# 711 es un número impar
# 712 es un número par
# 713 es un número impar
# 714 es un número par
# 715 es un número impar
# 716 es un número par
# 717 es un número impar
# 718 es un número par
# 719 es un número impar
# 720 es un número par
# 721 es un número impar
# 722 es un número par
# 723 es un número impar
# 724 es un número par
# 725 es un número impar
# 726 es un número par
# 727 es un número impar
# 728 es un número par
# 729 es un número impar
# 730 es un número par
# 731 es un número impar
# 732 es un número par
# 733 es un número impar
# 734 es un número par
# 735 es un número impar
# 736 es un número par
# 737 es un número impar
# 738 es un número par
# 739 es un número impar
# 740 es un número par
# 741 es un número impar
# 742 es un número par
# 743 es un número impar
# 744 es un número par
# 745 es un número impar
# 746 es un número par
# 747 es un número impar
# 748 es un número par
# 749 es un número impar
# 750 es un número par
# 751 es un número impar
# 752 es un número par
# 753 es un número impar
# 754 es un número par
# 755 es un número impar
# 756 es un número par
# 757 es un número impar
# 758 es un número par
# 759 es un número impar
# 760 es un número par
# 761 es un número impar
# 762 es un número par
# 763 es un número impar
# 764 es un número par
# 765 es un número impar
# 766 es un número par
# 767 es un número impar
# 768 es un número par
# 769 es un número impar
# 770 es un número par
# 771 es un número impar
# 772 es un número par
# 773 es un número impar
# 774 es un número par
# 775 es un número impar
# 776 es un número par
# 777 es un número impar
# 778 es un número par
# 779 es un número impar
# 780 es un número par
# 781 es un número impar
# 782 es un número par
# 783 es un número impar
# 784 es un número par
# 785 es un número impar
# 786 es un número par
# 787 es un número impar
# 788 es un número par
# 789 es un número impar
# 790 es un número par
# 791 es un número impar
# 792 es un número par
# 793 es un número impar
# 794 es un número par
# 795 es un número impar
# 796 es un número par
# 797 es un número impar
# 798 es un número par
# 799 es un número impar
# 800 es un número par
# 801 es un número impar
# 802 es un número par
# 803 es un número impar
# 804 es un número par
# 805 es un número impar
# 806 es un número par
# 807 es un número impar
# 808 es un número par
# 809 es un número impar
# 810 es un número par
# 811 es un número impar
# 812 es un número par
# 813 es un número impar
# 814 es un número par
# 815 es un número impar
# 816 es un número par
# 817 es un número impar
# 818 es un número par
# 819 es un número impar
# 820 es un número par
# 821 es un número impar
# 822 es un número par
# 823 es un número impar
# 824 es un número par
# 825 es un número impar
# 826 es un número par
# 827 es un número impar
# 828 es un número par
# 829 es un número impar
# 830 es un número par
# 831 es un número impar
# 832 es un número par
# 833 es un número impar
# 834 es un número par
# 835 es un número impar
# 836 es un número par
# 837 es un número impar
# 838 es un número par
# 839 es un número impar
# 840 es un número par
# 841 es un número impar
# 842 es un número par
# 843 es un número impar
# 844 es un número par
# 845 es un número impar
# 846 es un número par
# 847 es un número impar
# 848 es un número par
# 849 es un número impar
# 850 es un número par
# 851 es un número impar
# 852 es un número par
# 853 es un número impar
# 854 es un número par
# 855 es un número impar
# 856 es un número par
# 857 es un número impar
# 858 es un número par
# 859 es un número impar
# 860 es un número par
# 861 es un número impar
# 862 es un número par
# 863 es un número impar
# 864 es un número par
# 865 es un número impar
# 866 es un número par
# 867 es un número impar
# 868 es un número par
# 869 es un número impar
# 870 es un número par
# 871 es un número impar
# 872 es un número par
# 873 es un número impar
# 874 es un número par
# 875 es un número impar
# 876 es un número par
# 877 es un número impar
# 878 es un número par
# 879 es un número impar
# 880 es un número par
# 881 es un número impar
# 882 es un número par
# 883 es un número impar
# 884 es un número par
# 885 es un número impar
# 886 es un número par
# 887 es un número impar
# 888 es un número par
# 889 es un número impar
# 890 es un número par
# 891 es un número impar
# 892 es un número par
# 893 es un número impar
# 894 es un número par
# 895 es un número impar
# 896 es un número par
# 897 es un número impar
# 898 es un número par
# 899 es un número impar
# 900 es un número par
# 901 es un número impar
# 902 es un número par
# 903 es un número impar
# 904 es un número par
# 905 es un número impar
# 906 es un número par
# 907 es un número impar
# 908 es un número par
# 909 es un número impar
# 910 es un número par
# 911 es un número impar
# 912 es un número par
# 913 es un número impar
# 914 es un número par
# 915 es un número impar
# 916 es un número par
# 917 es un número impar
# 918 es un número par
# 919 es un número impar
# 920 es un número par
# 921 es un número impar
# 922 es un número par
# 923 es un número impar
# 924 es un número par
# 925 es un número impar
# 926 es un número par
# 927 es un número impar
# 928 es un número par
# 929 es un número impar
# 930 es un número par
# 931 es un número impar
# 932 es un número par
# 933 es un número impar
# 934 es un número par
# 935 es un número impar
# 936 es un número par
# 937 es un número impar
# 938 es un número par
# 939 es un número impar
# 940 es un número par
# 941 es un número impar
# 942 es un número par
# 943 es un número impar
# 944 es un número par
# 945 es un número impar
# 946 es un número par
# 947 es un número impar
# 948 es un número par
# 949 es un número impar
# 950 es un número par
# 951 es un número impar
# 952 es un número par
# 953 es un número impar
# 954 es un número par
# 955 es un número impar
# 956 es un número par
# 957 es un número impar
# 958 es un número par
# 959 es un número impar
# 960 es un número par
# 961 es un número impar
# 962 es un número par
# 963 es un número impar
# 964 es un número par
# 965 es un número impar
# 966 es un número par
# 967 es un número impar
# 968 es un número par
# 969 es un número impar
# 970 es un número par
# 971 es un número impar
# 972 es un número par
# 973 es un número impar
# 974 es un número par
# 975 es un número impar
# 976 es un número par
# 977 es un número impar
# 978 es un número par
# 979 es un número impar
# 980 es un número par
# 981 es un número impar
# 982 es un número par
# 983 es un número impar
# 984 es un número par
# 985 es un número impar
# 986 es un número par
# 987 es un número impar
# 988 es un número par
# 989 es un número impar
# 990 es un número par
# 991 es un número impar
# 992 es un número par
# 993 es un número impar
# 994 es un número par
# 995 es un número impar
# 996 es un número par
# 997 es un número impar
# 998 es un número par
# 999 es un número impar
